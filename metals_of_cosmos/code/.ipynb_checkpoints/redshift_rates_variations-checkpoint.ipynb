# %% [markdown]
# This notebook is to visualize the redshift vs rates plot for common envelope alpha variations

# %% [markdown]
# ### Imports and definitions

# %%
import h5py as h5 
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import tol_colors as tc

import useful_fncs
import utils_from_others
import figure_utils
import redshift_rates_fnc

# plotting imports
# import for axes labels 
plt.rc('text.latex', preamble=r'\usepackage{textgreek}')
plt.rc('font', family='serif')
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif"
})

# %% [markdown]
# ### Let's use our function to gather our data

# %%
pathToH5_NSNS_025 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_NSNS_CE_alpha025/MainRun/COMPAS_Output_wWeights.h5'
pathToH5_WDWD_025 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_MassiveWDWD_NSNS_CE_alpha025/MainRun/COMPAS_Output_wWeights.h5'

redshifts_025, rates_025, percentiles_025, ratios_025 = redshift_rates_fnc.redshift_rates_info(pathToH5_NSNS_025, pathToH5_WDWD_025)
# Out:
# Bootstrapping :[############################################################] 50/50

# %%
pathToH5_NSNS_05 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_NSNS_CE_alpha05/MainRun/COMPAS_Output_wWeights.h5'
pathToH5_WDWD_05 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_MassiveWDWD_NSNS_CE_alpha05/MainRun/COMPAS_Output_wWeights.h5'

redshifts_05, rates_05, percentiles_05, ratios_05 = redshift_rates_fnc.redshift_rates_info(pathToH5_NSNS_05, pathToH5_WDWD_05)
# Out:
# Bootstrapping :[############################################################] 50/50

# %%
pathToH5_NSNS_075 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_NSNS_CE_alpha075/MainRun/COMPAS_Output_wWeights.h5'
pathToH5_WDWD_075 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_MassiveWDWD_NSNS_CE_alpha075/MainRun/COMPAS_Output_wWeights.h5'

redshifts_075, rates_075, percentiles_075, ratios_075 = redshift_rates_fnc.redshift_rates_info(pathToH5_NSNS_075, pathToH5_WDWD_075)
# Out:
# Bootstrapping :[############################################################] 50/50

# %%
pathToH5_NSNS_2 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_NSNS_CE_alpha2/MainRun/COMPAS_Output_wWeights.h5'
pathToH5_WDWD_2 = '/expanse/lustre/scratch/msantiago/temp_project/COMPAS_DATA/N5e6_MassiveWDWD_NSNS_CE_alpha2/MainRun/COMPAS_Output_wWeights.h5'

redshifts_2, rates_2, percentiles_2, ratios_2 = redshift_rates_fnc.redshift_rates_info(pathToH5_NSNS_2, pathToH5_WDWD_2)
# Out:
# Bootstrapping :[############################################################] 50/50

# %% [markdown]
# ### Plotting

# %%
h_little = 0.6766

redshifts_briel = [
    0, 0.01, 0.03, (0.025+0.050)/2, 0.073, (0.05+0.15)/2, (0.075+0.125)/2, 0.11, 0.11, 0.13, 
    0.15, (0.125+0.175)/2, 0.16, (0.175+0.225)/2, 0.2, 0.25, (0.15+0.35)/2, (0.225+0.275)/2, 
    0.26, 0.3, (0.275+0.325)/2, 0.35, 0.35, 0.42, 0.44, 0.45, 0.45, (0.35+0.55)/2, 0.46, 0.47, 
    0.47, 0.55, 0.55, 0.55, 0.62, 0.65, (0.55+0.75)/2, 0.65, 0.74, 0.75, 0.75, 0.75, 0.8, 0.83, 0.85, 
    0.85, 0.94, 0.95, 0.95, 1.05, 1.1, 1.14, 1.21, 1.23, 1.25, 1.59, 1.61, 1.69, 1.75, 2.25
]

rates_briel = [
    0.77, 0.82, 0.82, 0.81, 0.71, 1.60, 0.76, 1.08, 0.72, 0.58, 0.93, 0.90, 0.41, 1.01, 0.58,
    1.05, 1.14, 1.06, 0.82, 0.99, 1.27, 0.99, 1.05, 1.34, 0.76, 0.90, 1.05, 1.52, 1.40, 1.22, 
    2.33, 0.93, 1.40, 1.52, 3.76, 1.40, 2.01, 1.43, 2.30, 1.49, 1.98, 1.69, 2.45, 3.79, 2.27, 
    1.66, 1.31, 2.22, 2.24, 2.30, 2.16, 2.06, 3.85, 2.45, 1.87, 1.31, 1.22, 2.97, 2.10, 1.43
]

# converting the rates to the correct units
rates_briel = np.array(rates_briel)
converted_rates_briel = (rates_briel*(10**5))*(h_little**3)

## uncertainties
lower_limits = [
    -0.10, -0.26, -0.32, -0.24, -0.08, -0.85, -0.13, -0.29, -0.20, -0.18, -0.67, -0.10, -0.26, -0.09, 
    -0.23, -0.76, -0.35, -0.08, -0.20, -0.44, -0.10, -0.55, -0.17, -0.93, -0.39, -0.44, -0.17, -0.38, 
    -0.50, -0.17, -0.79, -0.41, -0.17, -0.26, -1.66, -0.15, -0.52, -0.50, -1.20, -0.55, -0.61, -0.17, 
    -0.54, -0.79, -0.64, -0.15, -0.55, -0.73, -0.23, -0.82, -0.35, -0.53, -0.85, -0.82, -0.64, -0.64, 
    -0.67, -1.08, -0.87, -1.11
]

lower_limits = np.array(lower_limits)
converted_lower_limits = (lower_limits*(10**5)*(h_little**3))

upper_limits = [
    0.10, 0.26, 0.32, 0.33, 0.08, 1.46, 0.15, 0.29, 0.08, 0.20, 0.67, 0.11, 0.26, 0.09, 0.23,
    1.75, 0.38, 0.09, 0.20, 0.47, 0.11, 0.55, 0.17, 1.22, 0.67, 0.44, 0.17, 0.32, 0.50, 0.17, 
    1.08, 0.41, 0.17, 0.29, 2.57, 0.15, 0.55, 0.50, 0.96, 0.79, 0.61, 0.17, 0.67, 0.96, 0.64, 
    0.15, 0.64, 0.73, 0.23, 0.82, 0.35, 0.70, 1.05, 0.73, 0.90, 0.99, 1.14, 1.57, 1.31, 2.77
]

upper_limits = np.array(upper_limits)
converted_upper_limits = (upper_limits*(10**5)*(h_little**3))

# multiplied the lower errors by -1 so make them positive to avoid the plt.errorbar error 
y_error = [-1*(converted_lower_limits), converted_upper_limits]

# %%
# let's make the plot with just the WDWD progenitor systems

# plotting formation efficencies

fig, ax = plt.subplots(
    4, 2,
    sharex=True,
    figsize=(15, 9),
    gridspec_kw={"height_ratios": [1, 3, 1, 3]}
)
cset = tc.dark
cset_l = tc.light
cset_br = tc.bright

### CE 0.25
### ratios
ax[0,0].plot(redshifts_025[1], ratios_025[0], linewidth=2,color=cset_br.purple)
ax[0,0].plot(redshifts_025[1], ratios_025[1], linewidth=2,color=cset_br.blue)
ax[0,0].plot(redshifts_025[1], ratios_025[2], linewidth=2,color=cset_br.green)

ax[0,0].set_ylabel(r"$\mathcal{R}$/$\mathcal{R}_{\text{TOT DWD}}$",fontsize=15)

# observational constraints from Briel et al. 2023 Table A1 - https://academic.oup.com/mnras/article/514/1/1315/6576337
ax[1,0].errorbar(redshifts_briel,converted_rates_briel,yerr=y_error, fmt='o', color = 'slategrey', alpha=0.7)#,label='Briel et al. 2023')

# COWD
# ax.fill_between(redshifts_025[1], percentiles_025[1][0], percentiles_025[1][2], alpha = 0.3, color = 'royalblue')
# ax.plot(redshifts_025[1], percentiles_025[1][1],linewidth=1,color='mediumpurple', ls="--", alpha=0.7)#,label='WDWD rate bootstrapped median')
ax[1,0].plot(redshifts_025[1], rates_025[1], linewidth=2,color=cset_br.purple,label='COWD+WD merged')

# COWD super Chnadrasekhar
ax[1,0].plot(redshifts_025[1], rates_025[2], linewidth=2,color=cset_br.blue,label=r'COWD+WD merged: $\rm{M_{TOT}}>1.4\rm{M_{\odot}}$')


# HVS
ax[1,0].plot(redshifts_025[1], rates_025[3], linewidth=2,color=cset_br.green,label='$\mathrm{D^6}$ HVS')


# NSNS
ax[1,0].fill_between(redshifts_025[0], percentiles_025[0][0], percentiles_025[0][2], alpha = 0.3, color = cset_br.yellow)
ax[1,0].plot(redshifts_025[0], percentiles_025[0][1],linewidth=3,color='grey', ls="--", alpha=0.7)#,label='NSNS rate bootstrapped median')
ax[1,0].plot(redshifts_025[0], rates_025[0],linewidth=3, color=cset_br.yellow,alpha=0.7, label='NSNS merged')

## LVK BNS rate (update at z=0 - https://arxiv.org/abs/2605.27226)
ax[1,0].fill_between([0,0.05], 
                5.1,
                154.7, 
                alpha=0.15, 
                color="grey")#,label=r'LVK BNS Rate $\mathrm{z=0.2}$')

ax[1,0].set_yscale('log')
ax[1,0].set_ylabel(r"$\mathcal{R}$ [$\mathrm{dNdGpc^{-3}dyr^{-1}}$]",fontsize=15)
ax[1,0].tick_params(axis='x', length=8, width=1, labelsize=10)
ax[1,0].tick_params(axis='y', length=8, width=1, labelsize=10)
ax[1,0].legend(fontsize=8)
ax[0,0].set_title(r"$\alpha_{\mathrm{CE}}=0.25$", fontsize=15)





### CE 0.50
### ratios
ax[0,1].plot(redshifts_05[1], ratios_05[0], linewidth=2,color=cset_br.purple)
ax[0,1].plot(redshifts_05[1], ratios_05[1], linewidth=2,color=cset_br.blue)
ax[0,1].plot(redshifts_05[1], ratios_05[2], linewidth=2,color=cset_br.green)

# observational constraints from Briel et al. 2023 Table A1 - https://academic.oup.com/mnras/article/514/1/1315/6576337
ax[1,1].errorbar(redshifts_briel,converted_rates_briel,yerr=y_error, fmt='o', color = 'slategrey', alpha=0.7)#,label='Briel et al. 2023')

# COWD
# ax.fill_between(redshifts_05[1], percentiles_05[1][0], percentiles_05[1][2], alpha = 0.3, color = 'royalblue')
# ax.plot(redshifts_05[1], percentiles_05[1][1],linewidth=1,color='mediumpurple', ls="--", alpha=0.7)#,label='WDWD rate bootstrapped median')
ax[1,1].plot(redshifts_05[1], rates_05[1], linewidth=2,color=cset_br.purple,label='COWD+WD merged')

# COWD super Chnadrasekhar
ax[1,1].plot(redshifts_05[1], rates_05[2], linewidth=2,color=cset_br.blue,label=r'COWD+WD merged: $\rm{M_{TOT}}>1.4\rm{M_{\odot}}$')


# HVS
ax[1,1].plot(redshifts_05[1], rates_05[3], linewidth=2,color=cset_br.green,label='$\mathrm{D^6}$ HVS')


# NSNS
ax[1,1].fill_between(redshifts_05[0], percentiles_05[0][0], percentiles_05[0][2], alpha = 0.3, color = cset_br.yellow)
ax[1,1].plot(redshifts_05[0], percentiles_05[0][1],linewidth=3,color='grey', ls="--", alpha=0.7)#,label='NSNS rate bootstrapped median')
ax[1,1].plot(redshifts_05[0], rates_05[0],linewidth=3, color=cset_br.yellow,alpha=0.7, label='NSNS merged')

## LVK BNS rate (update at z=0 - https://arxiv.org/abs/2605.27226)
ax[1,1].fill_between([0,0.05], 
                5.1,
                154.7, 
                alpha=0.15, 
                color="grey")#,label=r'LVK BNS Rate $\mathrm{z=0.2}$')

ax[1,1].set_yscale('log')
ax[1,1].tick_params(axis='x', length=8, width=1, labelsize=10)
ax[1,1].tick_params(axis='y', length=8, width=1, labelsize=10)
ax[0,1].set_title(r"$\alpha_{\mathrm{CE}}=0.50$", fontsize=15)

ax[1,1].annotate("SN Ia Observations", xy=(1.25, 1.5*10**5), xytext=(2, 10**5), fontsize=12, color = 'slategrey', arrowprops=dict(facecolor='slategrey', alpha=0.7,arrowstyle='->'))
ax[1,1].annotate("LVK Observations", xy=(0.22, 10), xytext=(0.7, 8), fontsize=12, color='grey', arrowprops=dict(facecolor='slategrey', alpha=0.7,arrowstyle='->'))





### CE 0.75
### ratios
ax[2,0].plot(redshifts_075[1], ratios_075[0], linewidth=2,color=cset_br.purple)
ax[2,0].plot(redshifts_075[1], ratios_075[1], linewidth=2,color=cset_br.blue)
ax[2,0].plot(redshifts_075[1], ratios_075[2], linewidth=2,color=cset_br.green)

ax[2,0].set_ylabel(r"$\mathcal{R}$/$\mathcal{R}_{\text{TOT DWD}}$",fontsize=15)

# observational constraints from Briel et al. 2023 Table A1 - https://academic.oup.com/mnras/article/514/1/1315/6576337
ax[3,0].errorbar(redshifts_briel,converted_rates_briel,yerr=y_error, fmt='o', color = 'slategrey', alpha=0.7)#,label='Briel et al. 2023')

# COWD
# ax.fill_between(redshifts_075[1], percentiles_075[1][0], percentiles_075[1][2], alpha = 0.3, color = 'royalblue')
# ax.plot(redshifts_075[1], percentiles_075[1][1],linewidth=1,color='mediumpurple', ls="--", alpha=0.7)#,label='WDWD rate bootstrapped median')
ax[3,0].plot(redshifts_075[1], rates_075[1], linewidth=2,color=cset_br.purple,label='COWD+WD merged')

# COWD super Chnadrasekhar
ax[3,0].plot(redshifts_075[1], rates_075[2], linewidth=2,color=cset_br.blue,label=r'COWD+WD merged: $\rm{M_{TOT}}>1.4\rm{M_{\odot}}$')


# HVS
ax[3,0].plot(redshifts_075[1], rates_075[3], linewidth=2,color=cset_br.green,label='$\mathrm{D^6}$ HVS')


# NSNS
ax[3,0].fill_between(redshifts_075[0], percentiles_075[0][0], percentiles_075[0][2], alpha = 0.3, color = cset_br.yellow)
ax[3,0].plot(redshifts_075[0], percentiles_075[0][1],linewidth=3,color='grey', ls="--", alpha=0.7)#,label='NSNS rate bootstrapped median')
ax[3,0].plot(redshifts_075[0], rates_075[0],linewidth=3, color=cset_br.yellow,alpha=0.7, label='NSNS merged')

## LVK BNS rate (update at z=0 - https://arxiv.org/abs/2605.27226)
ax[3,0].fill_between([0,0.05], 
                5.1,
                154.7, 
                alpha=0.15, 
                color="grey")#,label=r'LVK BNS Rate $\mathrm{z=0.2}$')

ax[3,0].set_yscale('log')
ax[3,0].set_ylabel(r"$\mathcal{R}$ [$\mathrm{dNdGpc^{-3}dyr^{-1}}$]",fontsize=15)
ax[3,0].tick_params(axis='x', length=8, width=1, labelsize=10)
ax[3,0].tick_params(axis='y', length=8, width=1, labelsize=10)
ax[2,0].set_title(r"$\alpha_{\mathrm{CE}}=0.75$", fontsize=15)




# ### CE 2.00
# ### ratios
# ax[0].plot(redshifts_WDWD_CE025, cowd_rate_ratio, linewidth=2,color=cset_br.purple)
# ax[0].plot(redshifts_WDWD_CE025, super_chan_rate_ratio, linewidth=2,color=cset_br.blue)
# ax[0].plot(redshifts_WDWD_CE025, HVS_rate_ratio, linewidth=2,color=cset_br.green)

# ax[0].set_ylabel(r"$\mathcal{R}$/$\mathcal{R}_{\text{TOT DWD}}$",fontsize=15)

# # observational constraints from Briel et al. 2023 Table A1 - https://academic.oup.com/mnras/article/514/1/1315/6576337
# ax[1].errorbar(redshifts_briel,converted_rates_briel,yerr=y_error, fmt='o', color = 'slategrey', alpha=0.7)#,label='Briel et al. 2023')

# # COWD
# # ax.fill_between(redshifts_WDWD_CE025, percentiles_WDWD_CE025[0], percentiles_WDWD_CE025[2], alpha = 0.3, color = 'royalblue')
# # ax.plot(redshifts_WDWD_CE025, percentiles_WDWD_CE025[1],linewidth=1,color='mediumpurple', ls="--", alpha=0.7)#,label='WDWD rate bootstrapped median')
# ax[1].plot(redshifts_WDWD_CE025, cowd_rate_CE025, linewidth=2,color=cset_br.purple,label='COWD+WD merged')

# # COWD super Chnadrasekhar
# ax[1].plot(redshifts_WDWD_CE025, super_chan_rate_CE025, linewidth=2,color=cset_br.blue,label=r'COWD+WD merged: $\rm{M_{TOT}}>1.4\rm{M_{\odot}}$')


# # HVS
# ax[1].plot(redshifts_WDWD_CE025, HVS_rate_CE025, linewidth=2,color=cset_br.green,label='$\mathrm{D^6}$ HVS')


# # NSNS
# ax[1].fill_between(redshifts_NSNS_CE025, percentiles_CE025[0], percentiles_CE025[2], alpha = 0.3, color = cset_br.yellow)
# ax[1].plot(redshifts_NSNS_CE025, percentiles_CE025[1],linewidth=3,color='grey', ls="--", alpha=0.7)#,label='NSNS rate bootstrapped median')
# ax[1].plot(redshifts_NSNS_CE025, NSNS_rate_025,linewidth=3, color=cset_br.yellow,alpha=0.7, label='NSNS merged')

# ## LVK BNS rate (update at z=0 - https://arxiv.org/abs/2605.27226)
# ax[1].fill_between([0,0.05], 
#                 5.1,
#                 154.7, 
#                 alpha=0.15, 
#                 color="grey")#,label=r'LVK BNS Rate $\mathrm{z=0.2}$')

# ax[1].set_yscale('log')
# ax[1].set_ylabel(r"$\mathcal{R}$ [$\mathrm{dNdGpc^{-3}dyr^{-1}}$]",fontsize=25)
# ax[1].set_xlabel(r"Redshift",fontsize=25)
# ax[1].tick_params(axis='x', length=8, width=1, labelsize=18)
# ax[1].tick_params(axis='y', length=8, width=1, labelsize=18)
# ax[1].legend(fontsize=15)
# ax[0].set_title(r"Rates vs Redshift: $\alpha_{\mathrm{CE}}=0.25$", fontsize=25)

# make the ylabel shared so easier to comapre
ax[1,0].sharey(ax[1,1])
# ax[3,0].sharey(ax[3,1])

plt.subplots_adjust(hspace=0.35)

## save figure:
# plt.savefig("../figures/rates_redshift_CE025.png",bbox_inches='tight',pad_inches=0.1)
